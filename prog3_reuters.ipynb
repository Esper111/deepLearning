# %%
# 3.Classifying newswires: Multiclass classification using the Reuters dataset.

# %%
import numpy as np
import pandas as pd
# import warnings
import tensorflow as tf # import tensor flow
import numpy as np
import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import reuters
from tensorflow.keras.utils import to_categorical

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
train_data
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in
train_data[0]])
def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1.
  return results
x_train = vectorize_sequences(train_data)#1
x_test = vectorize_sequences(test_data)#2
# def to_one_hot(labels, dimension=46):
#   results = np.zeros((len(labels), dimension))
#   for i, label in enumerate(labels):
#     results[i, label] = 1.
#   return results
# one_hot_train_labels = to_one_hot(train_labels)#1
# one_hot_test_labels = to_one_hot(test_labels)#2

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)
model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(46, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]
history = model.fit(partial_x_train,
partial_y_train,
epochs=25,
batch_size=512,
validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2055 - loss: 3.6426 - val_accuracy: 0.5100 - val_loss: 2.7310
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.5940 - loss: 2.3377 - val_accuracy: 0.6540 - val_loss: 1.7245
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7100 - loss: 1.4636 - val_accuracy: 0.7220 - val_loss: 1.3054
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.7766 - loss: 1.0770 - val_accuracy: 0.7580 - val_loss: 1.1433
# Epoch 5/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8221 - loss: 0.8522 - val_accuracy: 0.7880 - val_loss: 1.0384
# Epoch 6/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.8636 - loss: 0.6880 - val_accuracy: 0.8000 - val_loss: 0.9667
# Epoch 7/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8927 - loss: 0.5326 - val_accuracy: 0.8060 - val_loss: 0.9269
# Epoch 8/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9151 - loss: 0.4102 - val_accuracy: 0.8140 - val_loss: 0.9006
# Epoch 9/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.9267 - loss: 0.3286 - val_accuracy: 0.8220 - val_loss: 0.8798
# Epoch 10/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9433 - loss: 0.2557 - val_accuracy: 0.8200 - val_loss: 0.8900
# Epoch 11/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9509 - loss: 0.2199 - val_accuracy: 0.8260 - val_loss: 0.8863
# Epoch 12/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9612 - loss: 0.1710 - val_accuracy: 0.8230 - val_loss: 0.9020
# Epoch 13/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9632 - loss: 0.1465 - val_accuracy: 0.8100 - val_loss: 0.9274
# Epoch 14/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9623 - loss: 0.1422 - val_accuracy: 0.8120 - val_loss: 0.9541
# Epoch 15/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9649 - loss: 0.1262 - val_accuracy: 0.8190 - val_loss: 0.9354
# Epoch 16/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9618 - loss: 0.1192 - val_accuracy: 0.8260 - val_loss: 0.9422
# Epoch 17/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9623 - loss: 0.1144 - val_accuracy: 0.8120 - val_loss: 0.9734
# Epoch 18/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9601 - loss: 0.1132 - val_accuracy: 0.8140 - val_loss: 0.9721
# Epoch 19/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9649 - loss: 0.0998 - val_accuracy: 0.8090 - val_loss: 1.0106
# Epoch 20/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9615 - loss: 0.1004 - val_accuracy: 0.8140 - val_loss: 0.9859
# Epoch 21/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.9632 - loss: 0.0926 - val_accuracy: 0.8110 - val_loss: 1.0130
# Epoch 22/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.
#        list([1, 227, 2406, 91, 2, 125, 2855, 21, 4, 3976, 76, 7, 4, 757, 481, 3976, 790, 5259, 5654, 9, 111, 149, 8, 7, 10, 76, 223, 51, 4, 417, 8, 1047, 91, 6917, 1688, 340, 7, 194, 9411, 6, 1894, 21, 127, 2151, 2394, 1456, 6, 3034, 4, 329, 433, 7, 65, 87, 1127, 10, 8219, 1475, 290, 9, 21, 567, 16, 1926, 24, 4, 76, 209, 30, 4033, 6655, 5654, 8, 4, 60, 8, 4, 966, 308, 40, 2575, 129, 2, 295, 277, 1071, 9, 24, 286, 2114, 234, 222, 9, 4, 906, 3994, 8519, 114, 5758, 1752, 7, 4, 113, 17, 12])],
#       dtype=object)

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in
train_data[0]])

# %%
def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1.
  return results

# %%
x_train = vectorize_sequences(train_data)#1
x_test = vectorize_sequences(test_data)#2

# %%
def to_one_hot(labels, dimension=46):
  results = np.zeros((len(labels), dimension))
  for i, label in enumerate(labels):
    results[i, label] = 1.
  return results

# %%
one_hot_train_labels = to_one_hot(train_labels)#1
one_hot_test_labels = to_one_hot(test_labels)#2

# %%
from tensorflow.keras.utils import to_categorical
one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
model = keras.Sequential([
layers.Dense(64, activation='relu'),
layers.Dense(64, activation='relu'),
layers.Dense(46, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train,
partial_y_train,
epochs=25,
batch_size=512,
validation_data=(x_val, y_val))
# Out:
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9624 - loss: 0.0765 - val_accuracy: 0.8040 - val_loss: 1.0985
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9618 - loss: 0.0780 - val_accuracy: 0.8030 - val_loss: 1.0675
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9609 - loss: 0.0792 - val_accuracy: 0.8080 - val_loss: 1.0552
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9614 - loss: 0.0764 - val_accuracy: 0.8120 - val_loss: 1.0466
# Epoch 5/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9631 - loss: 0.0737 - val_accuracy: 0.8060 - val_loss: 1.0489
# Epoch 6/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9636 - loss: 0.0731 - val_accuracy: 0.8030 - val_loss: 1.0837
# Epoch 7/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9625 - loss: 0.0763 - val_accuracy: 0.8080 - val_loss: 1.0535
# Epoch 8/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9634 - loss: 0.0801 - val_accuracy: 0.8060 - val_loss: 1.0638
# Epoch 9/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9684 - loss: 0.0667 - val_accuracy: 0.8050 - val_loss: 1.0490
# Epoch 10/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9646 - loss: 0.0781 - val_accuracy: 0.8010 - val_loss: 1.0647
# Epoch 11/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9625 - loss: 0.0771 - val_accuracy: 0.8080 - val_loss: 1.0927
# Epoch 12/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9605 - loss: 0.0784 - val_accuracy: 0.8080 - val_loss: 1.0632
# Epoch 13/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9619 - loss: 0.0728 - val_accuracy: 0.8010 - val_loss: 1.1415
# Epoch 14/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9642 - loss: 0.0741 - val_accuracy: 0.8190 - val_loss: 1.0357
# Epoch 15/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9592 - loss: 0.0794 - val_accuracy: 0.7960 - val_loss: 1.1448
# Epoch 16/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9616 - loss: 0.0791 - val_accuracy: 0.7960 - val_loss: 1.0944
# Epoch 17/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9618 - loss: 0.0783 - val_accuracy: 0.8140 - val_loss: 1.0469
# Epoch 18/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9672 - loss: 0.0668 - val_accuracy: 0.7960 - val_loss: 1.0632
# Epoch 19/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9656 - loss: 0.0699 - val_accuracy: 0.8070 - val_loss: 1.0355
# Epoch 20/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9652 - loss: 0.0709 - val_accuracy: 0.8120 - val_loss: 1.0381
# Epoch 21/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9626 - loss: 0.0721 - val_accuracy: 0.8060 - val_loss: 1.1014
# Epoch 22/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9642 - loss: 0.0689 - val_accuracy: 0.8040 - val_loss: 1.1066
# Epoch 23/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9680 - loss: 0.0679 - val_accuracy: 0.8040 - val_loss: 1.0562
# Epoch 24/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9635 - loss: 0.0728 - val_accuracy: 0.8040 - val_loss: 1.0723
# Epoch 25/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9626 - loss: 0.0754 - val_accuracy: 0.8080 - val_loss: 1.0588

# %%
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8016 - loss: 1.2117

# %% [markdown]
# CNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import reuters
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense

# Load the Reuters dataset
(X_train, y_train), (X_test, y_test) = reuters.load_data(num_words=10000)

# Preprocess the data: pad sequences to ensure uniform length
maxlen = 200
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

# Convert the labels to one-hot encoding
num_classes = np.max(y_train) + 1
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# Build the CNN model
model = Sequential([
    Embedding(input_dim=10000, output_dim=128, input_length=maxlen),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(units=128, activation='relu'),
    Dense(units=num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 109ms/step - accuracy: 0.4314 - loss: 2.4544 - val_accuracy: 0.6656 - val_loss: 1.3949
# Epoch 2/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 113ms/step - accuracy: 0.6833 - loss: 1.2958 - val_accuracy: 0.7401 - val_loss: 1.0902
# Epoch 3/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 40s 107ms/step - accuracy: 0.8095 - loss: 0.7864 - val_accuracy: 0.7746 - val_loss: 0.9438
# Epoch 4/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 117ms/step - accuracy: 0.8786 - loss: 0.5095 - val_accuracy: 0.7902 - val_loss: 0.9306
# Epoch 5/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 49s 154ms/step - accuracy: 0.9270 - loss: 0.3137 - val_accuracy: 0.7874 - val_loss: 0.9718
# Epoch 6/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 103ms/step - accuracy: 0.9527 - loss: 0.2210 - val_accuracy: 0.7852 - val_loss: 1.0492
# Epoch 7/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 108ms/step - accuracy: 0.9618 - loss: 0.1643 - val_accuracy: 0.7896 - val_loss: 1.0231
# Epoch 8/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 101ms/step - accuracy: 0.9634 - loss: 0.1588 - val_accuracy: 0.7880 - val_loss: 1.0197
# Epoch 9/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.9686 - loss: 0.1312 - val_accuracy: 0.7835 - val_loss: 1.0393
# Epoch 10/10
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 43s 116ms/step - accuracy: 0.9691 - loss: 0.1173 - val_accuracy: 0.7947 - val_loss: 1.0611
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8015 - loss: 1.0254
# Accuracy: 0.7867319583892822

# %% [markdown]
# Logistic Regression

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Load the dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.reuters.load_data(num_words=10000)

# Map the words back to their corresponding strings
word_index = tf.keras.datasets.reuters.get_word_index()

# Convert the integer-encoded sequences into actual words
def decode_sequence(sequence):
    reverse_word_index = {value: key for key, value in word_index.items()}
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in sequence])

x_train_text = [decode_sequence(seq) for seq in x_train]
x_test_text = [decode_sequence(seq) for seq in x_test]

# %%
# Vectorize the text using TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=5000)  # limit to top 5000 features
X_train_tfidf = vectorizer.fit_transform(x_train_text)
X_test_tfidf = vectorizer.transform(x_test_text)

# Encode the labels (targets) as integers
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Optionally, convert sparse matrices to dense for scikit-learn
X_train_dense = X_train_tfidf.toarray()
X_test_dense = X_test_tfidf.toarray()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Train a logistic regression model
logreg = LogisticRegression(max_iter=1000, multi_class='ovr', solver='liblinear')
logreg.fit(X_train_dense, y_train_encoded)

# Predict on the test set
y_pred = logreg.predict(X_test_dense)

# Evaluate the model
print(f'Accuracy: {accuracy_score(y_test_encoded, y_pred):.4f}')
print(f'Classification Report:\n{classification_report(y_test_encoded, y_pred)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Accuracy: 0.7939
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.50      0.63        12
#            1       0.64      0.83      0.72       105
#            2       0.92      0.60      0.73        20
#            3       0.92      0.94      0.93       813
#            4       0.72      0.92      0.81       474
#            5       0.00      0.00      0.00         5
#            6       0.92      0.79      0.85        14
#            7       1.00      0.33      0.50         3
#            8       0.72      0.61      0.66        38
#            9       0.92      0.92      0.92        25
#           10       0.96      0.80      0.87        30
#           11       0.63      0.81      0.71        83
#           12       1.00      0.23      0.38        13
#           13       0.68      0.62      0.65        37
#           14       1.00      0.50      0.67         2
#           15       0.00      0.00      0.00         9
#           16       0.70      0.79      0.74        99
#           17       1.00      0.08      0.15        12
#           18       0.62      0.65      0.63        20
#           19       0.68      0.76      0.72       133
#           20       0.79      0.47      0.59        70
#           21       0.70      0.78      0.74        27
#           22       0.00      0.00      0.00         7
#           23       0.67      0.17      0.27        12
#           24       1.00      0.11      0.19        19
#           25       0.96      0.71      0.81        31
#           26       1.00      0.25      0.40         8
#           27       0.00      0.00      0.00         4
#           28       0.33      0.10      0.15        10
#           29       0.00      0.00      0.00         4
#           30       0.60      0.25      0.35        12
#           31       0.00      0.00      0.00        13
#           32       1.00      0.70      0.82        10
#           33       0.00      0.00      0.00         5
#           34       1.00      0.71      0.83         7
#           35       0.00      0.00      0.00         6
#           36       0.67      0.18      0.29        11
#           37       1.00      0.50      0.67         2
#           38       0.00      0.00      0.00         3
#           39       0.00      0.00      0.00         5
#           40       0.00      0.00      0.00        10
#           41       1.00      0.12      0.22         8
#           42       0.00      0.00      0.00         3
#           43       1.00      0.17      0.29         6
#           44       1.00      0.80      0.89         5
#           45       1.00      1.00      1.00         1
#
#     accuracy                           0.79      2246
#    macro avg       0.62      0.41      0.45      2246
# weighted avg       0.78      0.79      0.77      2246
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
